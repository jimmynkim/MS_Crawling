# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import pandas as pd
import numpy as np
import time
from datetime import datetime
import math

# %% [markdown]
# #### 웹드라이버 생성 및 페이지 이동

# %%
driver = webdriver.Chrome()

# 웹페이지 접근
url = 'https://n.news.naver.com/article/005/0001707120'
driver.get(url)
driver.maximize_window()

# %% [markdown]
# #### 전체 댓글 수 추출

# %%
time.sleep(5)
review_total_cnt = driver.find_element(By.CSS_SELECTOR, "#comment_count").text

# %% [markdown]
# #### 댓글 화면으로 이동

# %%
time.sleep(2)
driver.find_element(By.CSS_SELECTOR, '#comment_count').click()

# %% [markdown]
# #### 더보기 클릭하여 모든 댓글 보이기

# %%
time.sleep(3)
# -----------------------------
# 더보기 클릭 횟수
#   더보기 클릭 할 때마다 20개의 댓글이 추가로 보여짐
#   ceil(전체 댓글 수/20)
# -----------------------------
# pagecnt = math.ceil(int(review_total_cnt)/20)-1
pagecnt = 3

# -----------------------------
# 더보기 클릭 
# -----------------------------
for i in range(pagecnt):
    print(f'{i}번째 페이지 로드중')
    driver.find_element(By.CSS_SELECTOR, '.u_cbox_btn_more').click()
    time.sleep(2)
    
print('모든 댓글 로드 완료')
# Out:
# 0번째 페이지 로드중
# 1번째 페이지 로드중
# 2번째 페이지 로드중
# 모든 댓글 로드 완료

# %% [markdown]
# #### 데이터 추출

# %%
# ------------------------------------------
# 댓글, 좋아요갯수, 싫어요갯수, 날짜
# ------------------------------------------

comments = driver.find_elements(By.CSS_SELECTOR, ".u_cbox_area")
comment_list = []
for comment in comments:
    try: review = comment.find_element(By.CSS_SELECTOR, ".u_cbox_contents").text
    except: review = np.nan

    try: reply_cnt = comment.find_element(By.CSS_SELECTOR, ".u_cbox_reply_cnt").text
    except: reply_cnt = np.nan

    try: recomm = comment.find_element(By.CSS_SELECTOR, ".u_cbox_cnt_recomm").text
    except: recomm = np.nan
    

    try: unrecomm = comment.find_element(By.CSS_SELECTOR, ".u_cbox_cnt_unrecomm").text
    except: unrecomm = np.nan

    try: date = comment.find_element(By.CSS_SELECTOR, ".u_cbox_date").text
    except: date = np.nan

    
    comment_list.append({"review":review, "reply_cnt":reply_cnt, 
                         "recomm":recomm, "unrecomm":unrecomm, "date":date})

# %% [markdown]
# #### 데이터 저장

# %%
# -------------------------------
# 데이터프레임 생성
# -------------------------------
df = pd.DataFrame(comment_list)

# -------------------------------
# 파일로 저장
# -------------------------------
prefix = datetime.now().strftime('%Y%m%d_%H%M%S')
file_path = f'data/{prefix}네이버뉴스_나이키'
df.to_csv(file_path+'.csv')
df.to_excel(file_path+'.xlsx')

df
# Out:
#                                                review reply_cnt recomm  \
# 0                            발볼이 넓은사람은 나이키가 불편해서 안신게됨        36   1095
# 1                                 난 나이키만 신는데? 신발은 나이키        47    968
# 2                                                 NaN        17    NaN
# 3                                 디자인으로 신는거지 발이 편하진않음        15    321
# 4         발이 더 편하거나 디자인이 좋거나 하는 신발들이 많아졌지 사실 경쟁력이 없잖아         4    204
# 5   뉴발란스가 확실히 편해요. 이번에 아디다스 삼바도 사봤는데 나이키보다는 편하더라고요...         3     88
# 6                                            발볼이 너무좁다         1     70
# 7   허구한날 한정판이라고 콜라보네뭐네 출시소식만 주구장창 뿌리고 막상 매장가면 그림자구...         0     64
# 8    잘나가던 시절에 충성 고객들이 나이가 들어버렸어...그러다 보니 브랜드도 같이 늙어버림         1     41
# 9        스케쳐스 한번 신어보세요. 착용감 최고고 디자인도 정말 굿이예요. 2개 있어요.         5     51
# 10  솔직히 나이키가 편하다고요..????진심 레알이세요??ㅋㅋ 그똑같은 가격대로 아디다...         0     36
# 11     제목다는 꼬라지보소... ㅉㅉㅉ “요새 누가 국민일보 봐요” ㅋㅋㅋㅋ 기분좋지? ㅎ         0     34
# 12                                         나이키 많이 신던데         0     28
# 13                                                NaN       NaN    NaN
# 14  아시아인과 아시아환경적측면을 많이 고려하지않는 브랜드같음. 옷은 절대적으로크고 길고...         0     25
# 15  나이키는 가격대비 품질이 엉망... 나이키보다 싸고 품질좋은 물건이 수두룩한데 모델...         0     20
# 16                                                NaN       NaN    NaN
# 17                                         PC하다가 망하겠네         1     19
# 18  솔직히 메이커 값임. 이넘들 인체공학적 편안함 같은건 신경도 안쓰는거 같은데. 그저...         0     19
# 19                           동양인은 발볼 넓어서 나이키랑은 잘 안맞는듯         0     17
# 20                          유행은 결국 돌고 돈다. 저가 매수 적기임!!         2     15
# 21                                                NaN         1    NaN
# 22                                          아식스가 대세인듯         0     15
# 23  옷이나 신발제질도 예전보다 질도많이떠러졌고 가격은 더올랐으니 구입하는 사람들이 저조...         0     11
# 24  흑인 뚱녀 모델 파급력이 큼 pc 폐미묻으면 외국에서도 죄다 나락가고있는데 꾸역꾸역...         0     11
# 25  90년대 나이키 발이 편하고 좋은신발이었는데. 요즘 그렇지도 않음....볼좁고 무겁...         0      8
# 26                                                NaN         2    NaN
# 27                                                NaN       NaN    NaN
# 28                                        브랜드는 프로스펙스지         2      9
# 29                                                NaN       NaN    NaN
# 30  이제 러닝용은 호카나 아식스가 좋은걸 신어보면 다 아니까. 발볼이 넓고 발등이 높은...         0      6
# 31  비전이 안보여서 하락세는 맞는데, 오리지날로 연명하는 아디다스보다는 백배 낫다… 포...         0      6
# 32                                나이키신발은 볼이너무좁아서 아파요.         0      6
# 33                           운동화 편한걸로 치면 아식스가 제일 편하더라         0     11
# 34             페미 뭍으면 안사게되더라... 대체 브랜드도 많고 앞으로 평생 안살듯         0      8
# 35                                                NaN       NaN    NaN
# 36                                                NaN       NaN    NaN
# 37                      이뿐데 어떤 디자인은 뒷꿈치 까짐 ㅜ 운동화인데...         0      5
# 38                                   난 아식스가 좋아 나이키 구려         0      5
# 39                                                NaN       NaN    NaN
# 40                                     남자라면 , 나이와 키지.         2      6
# 41  발은 뉴발이 젤 편하지 버질 형님 하늘나라가고 오프화이트 나이키 둘다망한거임 스캇이...         0      6
# 42                                                NaN       NaN    NaN
# 43                                                NaN       NaN    NaN
# 44  질좋고값싼브랜드가 많아 선택지가 다양해진시대라 나이키는 전 세계를 아우르던 시절 다...         0      4
# 45                                     ...신발은스케쳐스임...         0      4
# 46   나이키는 거지같은 흑인 모델부터 바꿔라 모델때문에 필라보다 더 싸구려 이미지 되는것같다         0      6
# 47  마라톤은 호카.. 농구는 언더아머.. 축구는 아디다스.. 일상화는 뉴발란스.. 노인...         1      3
